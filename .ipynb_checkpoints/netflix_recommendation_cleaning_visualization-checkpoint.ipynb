# %%
from pathlib import Path
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dir_to_scan = "/Users/keitabroadwater/data/netflix/data"
p = Path(dir_to_scan)

# %%
import pandas as pd

# %%
folders = []
files = []

for entry in os.scandir(p):
    if entry.is_dir():
        folders.append(entry)
    elif entry.is_file():
        files.append(entry)

print("Folders - {}".format(folders))
print("Files - {}".format(files))
# Out:
# Folders - []
# Files - [<DirEntry 'combined_data_2.txt'>, <DirEntry 'combined_data_3.txt'>, <DirEntry 'combined_data_1.txt'>, <DirEntry 'combined_data_4.txt'>]

# %%
if not os.path.isfile('data.csv'):

     data = open('data.csv',mode='w')


row = list()


for file in files:


    print("Reading ratings from {}..... ".format(file))


    with open(file) as f:


        for line in f:
            del row[:]
            line = line.strip()
            if line.endswith(':'):
                movie_id = line.replace(':',' ')
            else:
                row = [x for x in line.split(',')]
                row.insert(0,movie_id)
                data.write(','.join(row))  #error in this line
                data.write('\n')
    print("Done.\n")
data.close()
# Out:
# Reading ratings from <DirEntry 'combined_data_2.txt'>.....
# Done.
#
# Reading ratings from <DirEntry 'combined_data_3.txt'>.....
# Done.
#
# Reading ratings from <DirEntry 'combined_data_1.txt'>.....
# Done.
#
# Reading ratings from <DirEntry 'combined_data_4.txt'>.....
# Done.

# %%
data_all = pd.read_csv('data.csv', header = None, names = ['movie_id', 'user_id', 'rating', 'date'])

# %%
data_all['date'] = pd.to_datetime(data_all['date'])

# %%
data_all.tail()
# Out:
#            movie_id  user_id  rating       date
# 100480502     17770  1790158       4 2005-11-01
# 100480503     17770  1608708       3 2005-07-19
# 100480504     17770   234275       1 2004-08-07
# 100480505     17770   255278       4 2004-05-28
# 100480506     17770   453585       2 2005-03-10

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100480507 entries, 0 to 100480506
# Data columns (total 4 columns):
# movie_id    int64
# user_id     int64
# rating      int64
# date        datetime64[ns]
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 3.0 GB

# %%
data_all.drop_duplicates()

# %%
movie_titles = pd.read_csv('/Users/keitabroadwater/data/netflix/movie_titles.csv', header = None, names = ['movie_id', 'year', 'title'], usecols=[0,1,2],encoding = "ISO-8859-1")

# %%
movie_titles.head()
# Out:
#    movie_id    year                         title
# 0         1  2003.0               Dinosaur Planet
# 1         2  2004.0    Isle of Man TT 2004 Review
# 2         3  1997.0                     Character
# 3         4  1994.0  Paula Abdul's Get Up & Dance
# 4         5  2004.0      The Rise and Fall of ECW

# %%
ratings_by_title = data_all.groupby(['movie_id']).mean()['rating']

# %%
data_all.groupby(['movie_id']).mean()['rating']
# Out:
# movie_id
# 1        3.749543
# 2        3.558621
# 3        3.641153
# 4        2.739437
# 5        3.919298
# 6        3.084396
# 7        2.129032
# 8        3.189805
# 9        2.621053
# 10       3.180723
# 11       3.030303
# 12       3.417582
# 13       4.552000
# 14       3.025424
# 15       3.286207
# 16       3.098555
# 17       2.903208
# 18       3.784369
# 19       3.324675
# 20       3.146552
# 21       3.463303
# 22       2.246305
# 23       3.556098
# 24       2.993998
# 25       3.970174
# 26       2.793721
# 27       3.527473
# 28       3.823254
# 29       3.598470
# 30       3.761842
#            ...
# 17741    3.287242
# 17742    2.807259
# 17743    3.104945
# 17744    3.511628
# 17745    3.835237
# 17746    3.334702
# 17747    3.526796
# 17748    3.810989
# 17749    3.497238
# 17750    2.863636
# 17751    3.938182
# 17752    2.991537
# 17753    2.473054
# 17754    3.242347
# 17755    3.172662
# 17756    3.770464
# 17757    3.800000
# 17758    2.915531
# 17759    2.691275
# 17760    2.808126
# 17761    2.918348
# 17762    3.645749
# 17763    3.411855
# 17764    3.867112
# 17765    2.699681
# 17766    3.193388
# 17767    3.671569
# 17768    2.839207
# 17769    2.498592
# 17770    2.816504
# Name: rating, Length: 17770, dtype: float64

# %%
ratings_by_title.head()
# Out:
# movie_id
# 1    3.749543
# 2    3.558621
# 3    3.641153
# 4    2.739437
# 5    3.919298
# Name: rating, dtype: float64

# %%
ratings_dict = ratings_by_title.to_dict()

# %%
ratings_dict

# %%
def add_ratings(row):
    return ratings_dict[row['movie_id']]

# %%
movie_titles['avg_rating'] = movie_titles.apply (lambda row: add_ratings (row),axis=1)

# %%
movie_titles.head()
# Out:
#    movie_id    year                         title  avg_rating
# 0         1  2003.0               Dinosaur Planet    3.749543
# 1         2  2004.0    Isle of Man TT 2004 Review    3.558621
# 2         3  1997.0                     Character    3.641153
# 3         4  1994.0  Paula Abdul's Get Up & Dance    2.739437
# 4         5  2004.0      The Rise and Fall of ECW    3.919298

# %%
movie_titles.sort_values(by=['avg_rating'])
# Out:
#        movie_id    year                                              title  \
# 514         515  2005.0                                Avia Vampire Hunter
# 16486     16487  2004.0                                      Zodiac Killer
# 11767     11768  2004.0                           Alone in a Haunted House
# 17428     17429  2005.0                                  Vampire Assassins
# 3574       3575  2005.0                   The Worst Horror Movie Ever Made
# 17576     17577  2003.0                                         Absolution
# 8068       8069  2002.0                                             Ax 'Em
# 2425       2426  2004.0                          Dark Harvest 2: The Maize
# 4201       4202  2004.0                                         Half-Caste
# 1226       1227  2005.0                                  The Horror Within
# 13353     13354  2004.0                               Vampires vs. Zombies
# 1568       1569  2000.0                            The Bogus Witch Project
# 15572     15573  2005.0                                 Rise of the Undead
# 15686     15687  2004.0                                           Vampiyaz
# 624         625  1999.0                           Underground Comedy Movie
# 1724       1725  2003.0                                       Ben & Arthur
# 14596     14597  2003.0                                          Aquanoids
# 12728     12729  2004.0                                   Sweet Potato Pie
# 10331     10332  2001.0                                           Drive In
# 15915     15916  2000.0        Crazy Richard & I Can't Even Think Straight
# 5250       5251  2000.0            Caribbean Dreaming: U.S. Virgin Islands
# 14739     14740  1998.0                                           Seamless
# 11748     11749  2001.0                              Visions of Sugarplums
# 17607     17608  2004.0                                      Serial Slayer
# 5212       5213  2002.0                                 Legion of the Dead
# 3843       3844  2003.0                                      Midnight Mass
# 7186       7187  2000.0                                  Mr. Ice Cream Man
# 17730     17731  1998.0                                         Death Mask
# 14696     14697  1997.0                                         Pervirella
# 1790       1791  1999.0                                 Trailer: The Movie
# ...         ...     ...                                                ...
# 16264     16265  1977.0                  Star Wars: Episode IV: A New Hope
# 12292     12293  1972.0                                      The Godfather
# 7663       7664  2000.0                        Gladiator: Extended Edition
# 15295     15296  2001.0                                   Band of Brothers
# 3443       3444  2004.0              Family Guy: Freakin' Sweet Collection
# 16874     16875  2005.0                                     Ah! My Goddess
# 13503     13504  2004.0                                              House
# 16586     16587  1992.0                             The Simpsons: Season 4
# 12833     12834  2001.0                       Family Guy: Vol. 2: Season 3
# 11661     11662  2004.0                             The Sopranos: Season 5
# 5017       5018  2001.0                                      Fruits Basket
# 5102       5103  1993.0                             The Simpsons: Season 5
# 5581       5582  1980.0      Star Wars: Episode V: The Empire Strikes Back
# 14239     14240  2003.0          Lord of the Rings: The Return of the King
# 12           13  2003.0  Lord of the Rings: The Return of the King: Ext...
# 4237       4238  2000.0                                          Inu-Yasha
# 2101       2102  1994.0                             The Simpsons: Season 6
# 7832       7833  2004.0                     Arrested Development: Season 2
# 3032       3033  2005.0   Ghost in the Shell: Stand Alone Complex: 2nd Gig
# 12397     12398  2004.0                            Veronica Mars: Season 1
# 14549     14550  1994.0          The Shawshank Redemption: Special Edition
# 10463     10464  1995.0                              Tenchi Muyo! Ryo Ohki
# 8963       8964  2003.0                        Trailer Park Boys: Season 4
# 14790     14791  2003.0                        Trailer Park Boys: Season 3
# 15537     15538  2004.0                                Fullmetal Alchemist
# 9863       9864  2004.0                     Battlestar Galactica: Season 1
# 3455       3456  2004.0                                     Lost: Season 1
# 7056       7057  2002.0  Lord of the Rings: The Two Towers: Extended Ed...
# 7229       7230  2001.0  The Lord of the Rings: The Fellowship of the R...
# 14960     14961  2003.0  Lord of the Rings: The Return of the King: Ext...
#
#        avg_rating
# 514      1.287879
# 16486    1.346021
# 11767    1.375610
# 17428    1.396761
# 3574     1.400000
# 17576    1.400000
# 8068     1.422222
# 2425     1.452381
# 4201     1.487395
# 1226     1.496241
# 13353    1.496599
# 1568     1.497758
# 15572    1.502959
# 15686    1.503916
# 624      1.505034
# 1724     1.522137
# 14596    1.530387
# 12728    1.531496
# 10331    1.537634
# 15915    1.538012
# 5250     1.566372
# 14739    1.568627
# 11748    1.570461
# 17607    1.577947
# 5212     1.581395
# 3843     1.600000
# 7186     1.602410
# 17730    1.614286
# 14696    1.614679
# 1790     1.615385
# ...           ...
# 16264    4.504097
# 12292    4.504491
# 7663     4.512658
# 15295    4.513328
# 3443     4.516007
# 16874    4.521739
# 13503    4.522613
# 16586    4.523489
# 12833    4.527519
# 11661    4.534334
# 5017     4.538913
# 5102     4.542563
# 5581     4.543701
# 14239    4.545121
# 12       4.552000
# 4237     4.554434
# 2101     4.581296
# 7832     4.582389
# 3032     4.586364
# 12397    4.592084
# 14549    4.593384
# 10463    4.595506
# 8963     4.600000
# 14790    4.600000
# 15537    4.605021
# 9863     4.638809
# 3455     4.670989
# 7056     4.702611
# 7229     4.716611
# 14960    4.723270
#
# [17770 rows x 4 columns]

# %%
movie_titles.hist(column='avg_rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a66e5bda0>]],
#       dtype=object)

# %%
top_15 = movie_titles.sort_values(by=['avg_rating'],  ascending=False).head(15)
movie_titles.sort_values(by=['avg_rating'],  ascending=False).head(15)
# Out:
#        movie_id    year                                              title  \
# 14960     14961  2003.0  Lord of the Rings: The Return of the King: Ext...
# 7229       7230  2001.0  The Lord of the Rings: The Fellowship of the R...
# 7056       7057  2002.0  Lord of the Rings: The Two Towers: Extended Ed...
# 3455       3456  2004.0                                     Lost: Season 1
# 9863       9864  2004.0                     Battlestar Galactica: Season 1
# 15537     15538  2004.0                                Fullmetal Alchemist
# 8963       8964  2003.0                        Trailer Park Boys: Season 4
# 14790     14791  2003.0                        Trailer Park Boys: Season 3
# 10463     10464  1995.0                              Tenchi Muyo! Ryo Ohki
# 14549     14550  1994.0          The Shawshank Redemption: Special Edition
# 12397     12398  2004.0                            Veronica Mars: Season 1
# 3032       3033  2005.0   Ghost in the Shell: Stand Alone Complex: 2nd Gig
# 7832       7833  2004.0                     Arrested Development: Season 2
# 2101       2102  1994.0                             The Simpsons: Season 6
# 4237       4238  2000.0                                          Inu-Yasha
#
#        avg_rating
# 14960    4.723270
# 7229     4.716611
# 7056     4.702611
# 3455     4.670989
# 9863     4.638809
# 15537    4.605021
# 8963     4.600000
# 14790    4.600000
# 10463    4.595506
# 14549    4.593384
# 12397    4.592084
# 3032     4.586364
# 7832     4.582389
# 2101     4.581296
# 4237     4.554434

# %%
top_list = top_15['movie_id'].tolist()
top_list
# Out:
# [14961,
#  7230,
#  7057,
#  3456,
#  9864,
#  15538,
#  8964,
#  14791,
#  10464,
#  14550,
#  12398,
#  3033,
#  7833,
#  2102,
#  4238]

# %%
data_top_15 = data_all[data_all['movie_id'].isin(top_list)]
data_top_15.head()
# Out:
#           movie_id  user_id  rating       date
# 15891602      7057  1777904       5 2005-07-06
# 15891603      7057  2164355       5 2005-07-07
# 15891604      7057  1822148       4 2005-07-07
# 15891605      7057  1432761       5 2005-07-07
# 15891606      7057  2203206       5 2005-07-07

# %%
counts = data_top_15.groupby(['movie_id']).count()
counts
# Out:
#           user_id  rating    date
# movie_id
# 2102         8426    8426    8426
# 3033          220     220     220
# 3456         7249    7249    7249
# 4238         1883    1883    1883
# 7057        74912   74912   74912
# 7230        73422   73422   73422
# 7833         6621    6621    6621
# 8964           25      25      25
# 9864         1747    1747    1747
# 10464          89      89      89
# 12398        1238    1238    1238
# 14550      139660  139660  139660
# 14791          75      75      75
# 14961       73335   73335   73335
# 15538        1633    1633    1633

# %%
top_15b = pd.merge(top_15, counts, on='movie_id').drop(['rating', 'date'], axis=1)

# %%
top_15b.columns = ['movie_id', 'year', 'title', 'avg_rating', 'user_ratings_counts']

# %%
top_15b = top_15b.sort_values(by=['user_ratings_counts'], ascending=False)
top_15b
# Out:
#     movie_id    year                                              title  \
# 9      14550  1994.0          The Shawshank Redemption: Special Edition
# 2       7057  2002.0  Lord of the Rings: The Two Towers: Extended Ed...
# 1       7230  2001.0  The Lord of the Rings: The Fellowship of the R...
# 0      14961  2003.0  Lord of the Rings: The Return of the King: Ext...
# 13      2102  1994.0                             The Simpsons: Season 6
# 3       3456  2004.0                                     Lost: Season 1
# 12      7833  2004.0                     Arrested Development: Season 2
# 14      4238  2000.0                                          Inu-Yasha
# 4       9864  2004.0                     Battlestar Galactica: Season 1
# 5      15538  2004.0                                Fullmetal Alchemist
# 10     12398  2004.0                            Veronica Mars: Season 1
# 11      3033  2005.0   Ghost in the Shell: Stand Alone Complex: 2nd Gig
# 8      10464  1995.0                              Tenchi Muyo! Ryo Ohki
# 7      14791  2003.0                        Trailer Park Boys: Season 3
# 6       8964  2003.0                        Trailer Park Boys: Season 4
#
#     avg_rating  user_ratings_counts
# 9     4.593384               139660
# 2     4.702611                74912
# 1     4.716611                73422
# 0     4.723270                73335
# 13    4.581296                 8426
# 3     4.670989                 7249
# 12    4.582389                 6621
# 14    4.554434                 1883
# 4     4.638809                 1747
# 5     4.605021                 1633
# 10    4.592084                 1238
# 11    4.586364                  220
# 8     4.595506                   89
# 7     4.600000                   75
# 6     4.600000                   25

# %%
sns.set(style="darkgrid")

# %%
g = sns.barplot(x = top_15b.title, y = top_15b.user_ratings_counts)
plt.ylabel('count of user ratings')
# g.set_xticklabels(rotation=30)
loc, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0,0,'The Shawshank Redemption: Special Edition'),
#  Text(0,0,'Lord of the Rings: The Two Towers: Extended Edition'),
#  Text(0,0,'The Lord of the Rings: The Fellowship of the Ring: Extended Edition'),
#  Text(0,0,'Lord of the Rings: The Return of the King: Extended Edition'),
#  Text(0,0,'The Simpsons: Season 6'),
#  Text(0,0,'Lost: Season 1'),
#  Text(0,0,'Arrested Development: Season 2'),
#  Text(0,0,'Inu-Yasha'),
#  Text(0,0,'Battlestar Galactica: Season 1'),
#  Text(0,0,'Fullmetal Alchemist'),
#  Text(0,0,'Veronica Mars: Season 1'),
#  Text(0,0,'Ghost in the Shell: Stand Alone Complex: 2nd Gig'),
#  Text(0,0,'Tenchi Muyo! Ryo Ohki'),
#  Text(0,0,'Trailer Park Boys: Season 3'),
#  Text(0,0,'Trailer Park Boys: Season 4')]

# %%
h = sns.barplot(x = top_15b.title, y = top_15b.avg_rating)
plt.ylabel('average ratings')
loc, labels = plt.xticks()
h.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0,0,'The Shawshank Redemption: Special Edition'),
#  Text(0,0,'Lord of the Rings: The Two Towers: Extended Edition'),
#  Text(0,0,'The Lord of the Rings: The Fellowship of the Ring: Extended Edition'),
#  Text(0,0,'Lord of the Rings: The Return of the King: Extended Edition'),
#  Text(0,0,'The Simpsons: Season 6'),
#  Text(0,0,'Lost: Season 1'),
#  Text(0,0,'Arrested Development: Season 2'),
#  Text(0,0,'Inu-Yasha'),
#  Text(0,0,'Battlestar Galactica: Season 1'),
#  Text(0,0,'Fullmetal Alchemist'),
#  Text(0,0,'Veronica Mars: Season 1'),
#  Text(0,0,'Ghost in the Shell: Stand Alone Complex: 2nd Gig'),
#  Text(0,0,'Tenchi Muyo! Ryo Ohki'),
#  Text(0,0,'Trailer Park Boys: Season 3'),
#  Text(0,0,'Trailer Park Boys: Season 4')]
